# %%
import os
from src.cann.visualise import plot_param_trajectory

import matplotlib.pyplot as plt

# %%
! ls ../results

# %%
filenames = [
        os.path.join("results", "celu_l1_1", "exp.csv"),
        os.path.join("results", "silu_l1_1", "exp.csv"),
        os.path.join("results", "sigmoid_l1_1", "exp.csv"),
        os.path.join("results", "tanh_l1_1", "exp.csv"),
        os.path.join("results", "leakyrelu_l1_1", "exp.csv"),
        os.path.join("results", "poly_l1_1", "exp.csv"),
        os.path.join("results", "prelu_l1_1", "exp.csv"),
        os.path.join("results", "square_l1_1", "exp.csv"),
        os.path.join("results", "rootsquare_l1_1", "exp.csv"),
        os.path.join("results", "relu_l1_1", "exp.csv")]

for fn in filenames:
    ax_tag = os.path.split(os.path.split(fn)[0])[1]
    fig, ax = plot_param_trajectory(fn, ax_title=ax_tag)
    plt.show()

# %%
filenames = [os.path.join("results", "relu_l1_m", "exp.csv"),
        os.path.join("results", "poly_l1_m", "exp.csv"),
        os.path.join("results", "silu_l1_m", "exp.csv"),
        os.path.join("results", "prelu_l1_m", "exp.csv")]

for fn in filenames:
    ax_tag = os.path.split(os.path.split(fn)[0])[1]
    figs, axes = plot_param_trajectory(fn, ax_title=ax_tag)
    plt.show()
